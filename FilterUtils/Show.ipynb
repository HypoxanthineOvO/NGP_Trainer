# %%
import numpy as np
import os
from grid import DensityGrid

scenes = ["chair", "drums", "ficus", "hotdog", "lego", "materials", "mic", "ship"]

# %%
Base = "Inputs"
TYPE = "Hash19_Float"

for scene in scenes:
    path = f"./{Base}/{TYPE}/{scene}.msgpack"
    grid = DensityGrid(path)
    
    grid.display(title = f"{scene}", dpi = 60)
